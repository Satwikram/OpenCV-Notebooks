# %% [markdown]
# <a href="https://colab.research.google.com/github/Satwikram/OpenCV-Notebooks/blob/master/Grayscaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Grayscaling
#
# #### Grayscaling is process by which an image is converted from a full color to shades of grey (black & white)
#
# In OpenCV, many functions grayscale images before processing. This is done because it simplifies the image, acting almost as a noise reduction and increasing processing time as there is less information in the image.
#
# ### Let convert our color image to greyscale

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# Load our input image
image = cv2.imread('/content/drive/My Drive/OpenCV/HappyFish.jpg')
cv2_imshow(image)


# We use cvtColor, to convert to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

cv2_imshow( gray_image)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F72176E47F0>
# <PIL.Image.Image image mode=L size=259x194 at 0x7F72176D1EF0>

# %%
#Another method faster method
img = cv2.imread('/content/drive/My Drive/OpenCV/HappyFish.jpg',0)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=259x194 at 0x7F721766C390>
